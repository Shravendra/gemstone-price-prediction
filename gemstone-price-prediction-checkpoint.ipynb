# %%
import numpy as np   
import pandas as pd    
import seaborn as sns
import matplotlib.pyplot as plt   
# %matplotlib inline

# %%
df = pd.read_csv('cubic_zirconia.csv')
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
# drop the serial no column as it is useless for the model
df.columns.str.match("Unnamed")
df.loc[:,~df.columns.str.match("Unnamed")]
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
#Checking the number of columns in provided dataset.
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x',
#        'y', 'z', 'price'],
#       dtype='object')

# %%
#checking the data-type of each colums.
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# x             float64
# y             float64
# z             float64
# price           int64
# dtype: object

# %%
#checking the shape of dataset.
df.shape
# Out:
# (26967, 11)

# %%
#Getting the information data-types in column wise
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
df.isna().sum() #checking the NAN value is there or not.
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %%
len(df)
# Out:
# 26967

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# ...

# %%
#Removing the 1st column
df1 = df.drop('Unnamed: 0', axis=1)
df1
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
# Getting the summary statistics of the dataset
df1.describe()
# Out:
#               carat         depth         table             x             y  \
# count  26967.000000  26270.000000  26967.000000  26967.000000  26967.000000
# mean       0.798375     61.745147     57.456080      5.729854      5.733569
# std        0.477745      1.412860      2.232068      1.128516      1.166058
# min        0.200000     50.800000     49.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.710000
# 50%        0.700000     61.800000     57.000000      5.690000      5.710000
# 75%        1.050000     62.500000     59.000000      6.550000      6.540000
# max        4.500000     73.600000     79.000000     10.230000     58.900000
#
#                   z         price
# count  26967.000000  26967.000000
# mean       3.538057   3939.518115
# std        0.720624   4024.864666
# min        0.000000    326.000000
# 25%        2.900000    945.000000
# 50%        3.520000   2375.000000
# 75%        4.040000   5360.000000
# ...

# %%
# Getting the summary statistics of the  object variable.
df1.describe(include=['object'])
# Out:
#           cut  color clarity
# count   26967  26967   26967
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10816   5661    6571

# %%
# Checking for the values which are equal to zero.
print("Number of rows with x == 0: {} ".format((df1.x==0).sum()))
print("Number of rows with y == 0: {} ".format((df1.y==0).sum()))
print("Number of rows with z == 0: {} ".format((df1.z==0).sum()))
print("Number of rows with depth == 0: {} ".format((df1.depth==0).sum()))
# Out:
# Number of rows with x == 0: 3
# Number of rows with y == 0: 3
# Number of rows with z == 0: 9
# Number of rows with depth == 0: 0

# %%
df1.shape
# Out:
# (26967, 10)

# %%
#Dropping dimentionless diamonds
df1 = df1.drop(df1[df1["x"]==0].index)
df1 = df1.drop(df1[df1["y"]==0].index)
df1 = df1.drop(df1[df1["z"]==0].index)
df1.shape
# Out:
# (26958, 10)

# %%
#checking duplicate records in datasets.
dup = df1.duplicated()
print('Number of duplicate rows = %d' % (dup.sum()))
print(df1.shape)
# Out:
# Number of duplicate rows = 33
# (26958, 10)

# %%
print('Before',df1.shape)
df1.drop_duplicates(inplace=True) 
print('After',df1.shape)
# Out:
# Before (26958, 10)
# After (26925, 10)

# %%
dup = df1.duplicated()
print('Number of duplicate rows = %d' % (dup.sum()))
#now there no any duplicate record is present in datset.
# Out:
# Number of duplicate rows = 0

# %%
#Checking Missing values in dataset
df1.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
#Outlier Checks.
cols = ['carat','depth', 'table', 'x', 'y', 'z',
       'price' ]
for i in cols:
    sns.boxplot(df1[i],whis=1)
    plt.show();
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
#Outlier treatment :
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in df1[cols].columns:
    lr,ur=remove_outlier(df1[column])
    df1[column]=np.where(df1[column]>ur,ur,df1[column])
    df1[column]=np.where(df1[column]<lr,lr,df1[column])

# %%
cols = ['carat','depth', 'table', 'x', 'y', 'z',
       'price' ]
for i in cols:
    sns.boxplot(df1[i],whis=1.5)
    plt.show();
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Univariate_analysis

# %%
df1.hist(figsize=(20,30));

# %%
df1.skew()   # to measure the skeweness of every attribute.
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6560\425579630.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.skew()   # to measure the skeweness of every attribute.
# carat    0.917214
# depth   -0.025042
# table    0.480476
# x        0.397696
# y        0.394060
# z        0.394819
# price    1.157121
# dtype: float64

# %% [markdown]
# # Multivariate_Analysis

# %%
sns.pairplot(df1, hue = 'cut')

# %%
sns.set_palette("afmhot")
cols = ['x','y', 'z', 'table', 'depth']
c = 0

fig, axs = plt.subplots(ncols = len(cols), figsize=(20,7))

for i in cols:
    sns.scatterplot(data = df1, x = df1['price'], y = df1[i], ax = axs[c])
    c+=1

# %%
df1.shape

# %%
df1 = df1[(df1['x'] < 30)]
df1 = df1[(df1['y'] < 30)]
df1 = df1[(df1['z'] < 30) & (df1['z'] > 2)]
df1 = df1[(df1['table'] < 80) & (df1['table'] > 40)]
df1 = df1[(df1['depth'] < 75) & (df1['depth'] > 45)]

df1.shape
# Out:
# (26226, 10)

# %%
cols = ['x','y', 'z', 'table', 'depth']
c = 0

fig, axs = plt.subplots(ncols = len(cols), figsize=(20,7))

for i in cols:
    sns.scatterplot(data = df1, x = df1['price'], y = df1[i], ax = axs[c])
    c+=1

# %% [markdown]
# # This looks much cleaner and will give us better results

# %%
#Let's also have a look at the categorial features

print(df1.color.unique())
print(df1.cut.unique())
print(df1.clarity.unique())
# Out:
# ['E' 'G' 'F' 'D' 'H' 'J' 'I']
# ['Ideal' 'Premium' 'Very Good' 'Good' 'Fair']
# ['SI1' 'IF' 'VVS2' 'VS1' 'VVS1' 'VS2' 'SI2' 'I1']

# %%
cats = ['color', 'cut', 'clarity']
c = 0

fig, axs = plt.subplots(ncols = len(cats), nrows = 2, sharex='col', figsize=(20,13))

for i in cats:
    sns.countplot(data = df1, x = df1[i], ax = axs[0,c])
    sns.boxplot(data = df1, x = df1[i], y = df1['price'], ax = axs[1,c])
    c+=1

# %% [markdown]
# # Converting Categorial values

# %%
df1_num = df1.copy()

# %%
#Converting Categorial to numeric values

cats = ['color', 'cut', 'clarity']

for i in cats:
    df1_num[i+'_numeric'] = pd.factorize(df1_num[i])[0]
    df1_num.drop(i, axis = 1, inplace = True)

# %%
#So, now we have a dataframe with only numeric values
df1_num = df1_num.rename(columns = {'color_numeric': 'color', 'cut_numeric': 'cut', 'clarity_numeric': 'clarity'})
df1_num.head()
# Out:
#    carat  depth  table     x     y     z   price  color  cut  clarity
# 0   0.30   62.1   58.0  4.27  4.29  2.66   499.0      0    0        0
# 1   0.33   60.8   58.0  4.42  4.46  2.70   984.0      1    1        1
# 2   0.90   62.2   60.0  6.04  6.12  3.78  6289.0      0    2        2
# 3   0.42   61.6   56.0  4.82  4.80  2.96  1082.0      2    0        3
# 4   0.31   60.4   59.0  4.35  4.43  2.65   779.0      2    0        4

# %%
#Are there correlations between the features?
df1_num.corr()
# Out:
#             carat     depth     table         x         y         z     price  \
# carat    1.000000  0.033702  0.187471  0.982856  0.981939  0.981797  0.936570
# depth    0.033702  1.000000 -0.293946 -0.018574 -0.022260  0.101382  0.000326
# table    0.187471 -0.293946  1.000000  0.199910  0.194374  0.160965  0.138175
# x        0.982856 -0.018574  0.199910  1.000000  0.998476  0.991812  0.913227
# y        0.981939 -0.022260  0.194374  0.998476  1.000000  0.991458  0.914663
# z        0.981797  0.101382  0.160965  0.991812  0.991458  1.000000  0.909290
# price    0.936570  0.000326  0.138175  0.913227  0.914663  0.909290  1.000000
# color    0.249228  0.047575  0.024210  0.232391  0.232194  0.236500  0.142123
# cut      0.142524  0.215071  0.437229  0.133312  0.133217  0.158097  0.069184
# clarity  0.121446 -0.003521  0.038074  0.118309  0.115611  0.116661  0.062085
#
#             color       cut   clarity
# carat    0.249228  0.142524  0.121446
# ...

# %%
figure, ax = plt.subplots(figsize=(12,10))

sns.heatmap(df1_num.corr(), annot = True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# We can observe high correlations from x,y,z and carat to the price. The other features show low correlation to the price.

# %% [markdown]
# # Building Pipelines for standardization of the data and model-building for multiple regressors

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
#splitting the dataset in test and train data. The Price will be the Target and the other columns the features:

X = df1_num.drop('price', axis = 1)
y = df1_num['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
#Building the Pipelines

#Linear Regression
lr_pipeline = Pipeline([
    ('scaler_1', StandardScaler()),
    ('lr_classifier', LinearRegression())
])

#KNN
knn_pipeline = Pipeline([
    ('scaler_2', StandardScaler()),
    ('knn_classifier', KNeighborsRegressor())
])

#XGB
xgb_pipeline = Pipeline([
    ('scaler_3', StandardScaler()),
    ('xgb_classifier', XGBRegressor())
])

#Decision Tree
dt_pipeline = Pipeline([
    ('scaler_4', StandardScaler()),
    ('dt_classifier', DecisionTreeRegressor())
])

#Random Forest
rf_pipeline = Pipeline([
    ('scaler_5', StandardScaler()),
    ('rf_classifier', RandomForestRegressor())
])

pipelines = [lr_pipeline, knn_pipeline, xgb_pipeline, dt_pipeline, rf_pipeline]
models = ['Linear Regression', 'KNN', 'XGB', 'Decision Tree', 'Random Forest']

# %% [markdown]
# Now that we have the pipelines, we can fit our models to the training data:

# %%
for i in pipelines:
    i.fit(X_train, y_train)

# %%
cv_results = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train,y_train,scoring="neg_root_mean_squared_error", cv=10)
    cv_results.append(cv_score)
    print("%s: %f " % (models[i], cv_score.mean()))
# Out:
# Linear Regression: -1103.217185
# KNN: -698.413334
# XGB: -406.445564
# Decision Tree: -563.868431
# Random Forest: -415.177672

# %% [markdown]
# Let's make the predictions and then print out the metrics for measuring our model

# %%
pred = xgb_pipeline.predict(X_test)

# %%
print("MSE:",metrics.mean_squared_error(y_test, pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
print("MAE:",metrics.mean_absolute_error(y_test, pred))
print("R²:",metrics.r2_score(y_test, pred))
print("Adjusted R²:",1 - (1-metrics.r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# MSE: 148959.81422553072
# RMSE: 385.9531243888702
# MAE: 224.3650830437429
# R²: 0.9875679084480011
# Adjusted R²: 0.9875508183572774

# %% [markdown]
# Visualizing the predictions

# %%
plt.figure(figsize = (20, 12))
x_ax = range(len(y_test))
sns.lineplot(x = x_ax, y = y_test, label="original")
sns.lineplot(x = x_ax, y = pred, label="predicted", color = 'green')
plt.title("Actual vs. Predicted Diamond Prices")
plt.legend(loc = 'upper right')
plt.show()
